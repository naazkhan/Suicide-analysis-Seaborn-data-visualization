# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import os

# %%
data=pd.read_csv("/Users/naaz.27khan/Downloads/suicide.csv")

# %%
data.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN      2,156,624,900
# 1               5.19  Albania1987           NaN      2,156,624,900
# 2               4.83  Albania1987           NaN      2,156,624,900
# 3               4.59  Albania1987           NaN      2,156,624,900
# 4               3.28  Albania1987           NaN      2,156,624,900
#
#    gdp_per_capita ($)       generation
# 0                 796     Generation X
# 1                 796           Silent
# 2                 796     Generation X
# ...

# %%
data.reset_index()
# Out:
#        index     country  year     sex          age  suicides_no  population  \
# 0          0     Albania  1987    male  15-24 years           21      312900
# 1          1     Albania  1987    male  35-54 years           16      308000
# 2          2     Albania  1987  female  15-24 years           14      289700
# 3          3     Albania  1987    male    75+ years            1       21800
# 4          4     Albania  1987    male  25-34 years            9      274300
# 5          5     Albania  1987  female    75+ years            1       35600
# 6          6     Albania  1987  female  35-54 years            6      278800
# 7          7     Albania  1987  female  25-34 years            4      257200
# 8          8     Albania  1987    male  55-74 years            1      137500
# 9          9     Albania  1987  female   5-14 years            0      311000
# 10        10     Albania  1987  female  55-74 years            0      144600
# ...

# %%
df=data.drop(['HDI for year','country-year'],axis=1)
df.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop  gdp_for_year ($)   gdp_per_capita ($)       generation
# 0               6.71      2,156,624,900                 796     Generation X
# 1               5.19      2,156,624,900                 796           Silent
# 2               4.83      2,156,624,900                 796     Generation X
# 3               4.59      2,156,624,900                 796  G.I. Generation
# 4               3.28      2,156,624,900                 796          Boomers

# %%
df.describe()
# Out:
#                year   suicides_no    population  suicides/100k pop  \
# count  27820.000000  27820.000000  2.782000e+04       27820.000000
# mean    2001.258375    242.574407  1.844794e+06          12.816097
# std        8.469055    902.047917  3.911779e+06          18.961511
# min     1985.000000      0.000000  2.780000e+02           0.000000
# 25%     1995.000000      3.000000  9.749850e+04           0.920000
# 50%     2002.000000     25.000000  4.301500e+05           5.990000
# 75%     2008.000000    131.000000  1.486143e+06          16.620000
# max     2016.000000  22338.000000  4.380521e+07         224.970000
#
#        gdp_per_capita ($)
# count        27820.000000
# mean         16866.464414
# std          18887.576472
# min            251.000000
# 25%           3447.000000
# 50%           9372.000000
# 75%          24874.000000
# max         126352.000000

# %%
df.columns
# Out:
# Index(['country', 'year', 'sex', 'age', 'suicides_no', 'population',
#        'suicides/100k pop', ' gdp_for_year ($) ', 'gdp_per_capita ($)',
#        'generation'],
#       dtype='object')

# %%
p = sns.countplot(x="sex", data=df)

# %%
corr= sns.heatmap(df.corr(), annot=True)

# %%
p1 = sns.barplot(x='sex', y='suicides_no', hue='age', data=df)

# %%
p2 = sns.barplot(x='sex', y='suicides_no', hue='generation', data=df)

# %%
p3=sns.lineplot(x='population',y='suicides_no',data=df)

# %%
p3=sns.lineplot(x='population',y='suicides_no',hue='year',data=df)

# %%
p3=sns.barplot(x='year',y='suicides_no',data=df)

# %%
male_population = df.loc[df.loc[:, 'sex']=='male',:]
female_population = df.loc[df.loc[:, 'sex']=='female',:]

# %%
p = sns.lineplot(x='year', y='suicides_no', data=male_population)
q = sns.lineplot(x='year', y='suicides_no', data=female_population)

_ = plt.legend(['males', 'females'])

# %%
fig=sns.jointplot(y='suicides_no',x='population',data=df,color="b")
plt.show()

# %%
fig=sns.jointplot(y='gdp_per_capita ($)',x='suicides_no',kind='hex',data=df[df['country']=='United States'])
plt.show()

# %%
sns.pairplot(df,hue='generation')
plt.show()

# %%
sns.boxenplot(x="generation", y="suicides_no",
              color="b",
              scale="linear", data=df)
plt.tight_layout()
plt.show()

# %%
sns.boxenplot(x="sex", y="suicides_no",
              color="c",
              scale="linear", data=df)
plt.tight_layout()
plt.show()
